# %% [markdown]
# # Step 1: Install MLflow

# %%
# !pip install --upgrade "mlflow>=3.1"
# Out:
# Requirement already satisfied: mlflow>=3.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: mlflow-skinny==3.8.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (3.8.1)
# Requirement already satisfied: mlflow-tracing==3.8.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (3.8.1)
# Requirement already satisfied: Flask-CORS<7 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (6.0.2)
# Requirement already satisfied: Flask<4 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (1.17.2)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (7.1.0)
# Requirement already satisfied: graphene<4 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (23.0.0)
# Requirement already satisfied: huey<3,>=2.5.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (2.5.5)
# Requirement already satisfied: matplotlib<4 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (3.10.8)
# Requirement already satisfied: numpy<3 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (2.2.6)
# Requirement already satisfied: pandas<3 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (2.3.3)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (1.7.2)
# Requirement already satisfied: scipy<2 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow>=3.1) (2.0.45)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (6.2.4)
# Requirement already satisfied: click<9,>=7.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (8.3.1)
# Requirement already satisfied: cloudpickle<4 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (0.76.0)
# Requirement already satisfied: fastapi<1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (0.128.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (8.7.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (1.39.1)
# Requirement already satisfied: packaging<26 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (25.0)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (6.33.2)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (1.2.1)
# Requirement already satisfied: pyyaml<7,>=5.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (0.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from mlflow-skinny==3.8.1->mlflow>=3.1) (0.40.0)
# Requirement already satisfied: Mako in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow>=3.1) (1.3.10)
# Requirement already satisfied: tomli in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow>=3.1) (2.3.0)
# Requirement already satisfied: cffi>=2.0.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from cryptography<47,>=43.0.0->mlflow>=3.1) (2.0.0)
# Requirement already satisfied: google-auth~=2.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow>=3.1) (2.45.0)
# Requirement already satisfied: urllib3>=1.26.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow>=3.1) (2.6.2)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow>=3.1) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from fastapi<1->mlflow-skinny==3.8.1->mlflow>=3.1) (0.0.4)
# Requirement already satisfied: blinker>=1.9.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from Flask<4->mlflow>=3.1) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from Flask<4->mlflow>=3.1) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from Flask<4->mlflow>=3.1) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from Flask<4->mlflow>=3.1) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from Flask<4->mlflow>=3.1) (3.1.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow>=3.1) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.8.1->mlflow>=3.1) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow>=3.1) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow>=3.1) (4.9.1)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from graphene<4->mlflow>=3.1) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from graphene<4->mlflow>=3.1) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from graphene<4->mlflow>=3.1) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.8.1->mlflow>=3.1) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from matplotlib<4->mlflow>=3.1) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from matplotlib<4->mlflow>=3.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from matplotlib<4->mlflow>=3.1) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from matplotlib<4->mlflow>=3.1) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from matplotlib<4->mlflow>=3.1) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from matplotlib<4->mlflow>=3.1) (3.3.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.8.1->mlflow>=3.1) (0.60b1)
# Requirement already satisfied: pytz>=2020.1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from pandas<3->mlflow>=3.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from pandas<3->mlflow>=3.1) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow>=3.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow>=3.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.8.1->mlflow>=3.1) (0.4.2)
# Requirement already satisfied: six>=1.5 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow>=3.1) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow>=3.1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow>=3.1) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.8.1->mlflow>=3.1) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.8.1->mlflow>=3.1) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from scikit-learn<2->mlflow>=3.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from scikit-learn<2->mlflow>=3.1) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow>=3.1) (3.3.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow>=3.1) (4.12.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.8.1->mlflow>=3.1) (1.3.1)
# Requirement already satisfied: h11>=0.8 in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from uvicorn<1->mlflow-skinny==3.8.1->mlflow>=3.1) (0.16.0)
# Requirement already satisfied: pycparser in /home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow>=3.1) (2.23)

# %% [markdown]
# # Step 2: Configure Tracking

# %% [markdown]
# ## Option A: Database (Recommended)

# %%
import mlflow

mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("my-first-experiment")
# Out:
# <Experiment: artifact_location='/home/junspring/mlflow-jjb/mlruns/1', creation_time=1767009468836, experiment_id='1', last_update_time=1767009468836, lifecycle_stage='active', name='my-first-experiment', tags={}>

# %% [markdown]
# ## Option B: File System

# %%
# import mlflow

# # Creates local mlruns directory for experiments
# mlflow.set_experiment("my-first-experiment")
# Out:
# <Experiment: artifact_location='/home/junspring/mlflow-jjb/mlruns/1', creation_time=1767009468836, experiment_id='1', last_update_time=1767009468836, lifecycle_stage='active', name='my-first-experiment', tags={}>

# %% [markdown]
# # Step 3: Verify Your Connection

# %%
import mlflow

# Print connection information
print(f"MLflow Tracking URI: {mlflow.get_tracking_uri()}")
print(f"Active Experiment: {mlflow.get_experiment_by_name('my-first-experiment')}")

# Test logging
with mlflow.start_run():
    mlflow.log_param("test_param", "test_value")
    print("✓ Successfully connected to MLflow!")
# Out:
# MLflow Tracking URI: sqlite:///mlflow.db
# Active Experiment: <Experiment: artifact_location='/home/junspring/mlflow-jjb/mlruns/1', creation_time=1767009468836, experiment_id='1', last_update_time=1767009468836, lifecycle_stage='active', name='my-first-experiment', tags={}>
# ✓ Successfully connected to MLflow!

# %% [markdown]
# # Step 4: Access MLflow UI

# %%
# For Option A
# !mlflow server --backend-store-uri sqlite:///mlflow.db --port 5000
# # For Option B
# mlflow server --port 5000
# Out:
# Registry store URI not provided. Using backend store URI.
# 2025/12/29 21:00:50 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/29 21:00:50 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/29 21:00:50 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/29 21:00:50 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/29 21:00:50 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/29 21:00:50 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# 2025/12/29 21:00:50 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2025/12/29 21:00:50 INFO mlflow.store.db.utils: Updating database tables
# 2025/12/29 21:00:50 INFO alembic.runtime.migration: Context impl SQLiteImpl.
# 2025/12/29 21:00:50 INFO alembic.runtime.migration: Will assume non-transactional DDL.
# [MLflow] Security middleware enabled with default settings (localhost-only). To allow connections from other hosts, use --host 0.0.0.0 and configure --allowed-hosts and --cors-allowed-origins.
# INFO:     Uvicorn running on http://127.0.0.1:5000 (Press CTRL+C to quit)
# INFO:     Started parent process [12768]
# INFO:     Started server process [12770]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [12772]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [12773]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [12771]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Shutting down
# ^C
#
# Aborted!
# INFO:     Shutting down
# INFO:     Shutting down
# INFO:     Shutting down
# INFO:     Finished server process [12773]
# ERROR:    Traceback (most recent call last):
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/_compat.py", line 60, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/queues.py", line 159, in get
#     await getter
# asyncio.exceptions.CancelledError
#
# INFO:     Finished server process [12771]
# ERROR:    Traceback (most recent call last):
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/_compat.py", line 60, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/queues.py", line 159, in get
#     await getter
# asyncio.exceptions.CancelledError
#
# INFO:     Finished server process [12770]
# ERROR:    Traceback (most recent call last):
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/_compat.py", line 60, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/queues.py", line 159, in get
#     await getter
# asyncio.exceptions.CancelledError
#
# INFO:     Finished server process [12772]
# ERROR:    Traceback (most recent call last):
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/_compat.py", line 60, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/server.py", line 70, in serve
#     with self.capture_signals():
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/contextlib.py", line 142, in __exit__
#     next(self.gen)
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/server.py", line 331, in capture_signals
#     signal.raise_signal(captured_signal)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#   File "/home/junspring/anaconda3/envs/mlflow-env/lib/python3.10/asyncio/queues.py", line 159, in get
#     await getter
# asyncio.exceptions.CancelledError

# %% [markdown]
# http://localhost:5000
